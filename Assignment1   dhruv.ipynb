# %%
My_list=["revati","dhruv","rishi","pratiksha"]
print("\nmylist:",My_list)
# Out:
# mylist: ['revati', 'dhruv', 'rishi', 'pratiksha']

# %%
my_tuple=("revati","dhruv","rishi","pratiksha")
print("\nmytuple:",my_tuple)
# Out:
# mytuple: ('revati', 'dhruv', 'rishi', 'pratiksha')

# %%
my_dict={100:"revati",101:"dhruv",102:"rishi",103:"pratiksha"}
print("\nmydictionary:",my_dict)
# Out:
# mydictionary: {100: 'revati', 101: 'dhruv', 102: 'rishi', 103: 'pratiksha'}

# %%
my_dict[104]="darke"
print("\after adding:")
print(my_dict)
# Out:
# fter adding:
# {100: 'revati', 101: 'dhruv', 102: 'rishi', 103: 'pratiksha', 104: 'darke'}

# %%
my_dict[100]="revati mahle"
print("\after updating:",my_dict)
# Out:
# fter updating: {100: 'revati mahle', 101: 'dhruv', 102: 'rishi', 103: 'pratiksha', 104: 'darke'}

# %%
del my_dict[104]
print("After deleting:",my_dict)
# Out:
# After deleting: {100: 'revati mahle', 101: 'dhruv', 102: 'rishi', 103: 'pratiksha'}
